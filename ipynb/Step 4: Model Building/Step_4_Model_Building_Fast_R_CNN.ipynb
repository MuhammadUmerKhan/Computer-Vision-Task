# %%
# !pip install xmltodict torchmetrics
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.11/dist-packages (0.14.2)
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.5.1+cu124)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.12.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 21.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.12.0-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 25.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.12.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchmetrics-1.6.1

# %%
# !unzip FilteredData.zip
# Out:
# Archive:  FilteredData.zip
#    creating: Filtered Data/
#    creating: Filtered Data/filtered_images/
#    creating: Filtered Data/filtered_images/train/
#   inflating: Filtered Data/filtered_images/train/1_Renew_Licenced_Small_1_2022.png
#   inflating: Filtered Data/filtered_images/train/1010_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/1011_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/1032_Expired_Notified_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/1033_Expired_Notified_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/1039_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/106_Renew_Licenced_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/1060_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/1072_licenced_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/1082_licenced_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/1084_Expired_Notified_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/1089_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/1098_licenced_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/1106_licenced_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/1109_Expired_Notified_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/1134_Expired_Notified_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/1137_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/1148_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/1150_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/119_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/1198_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/12_licenced_Small_1_2023.png
#   inflating: Filtered Data/filtered_images/train/1207_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/1210_licenced_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/180_licenced_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/2_Expired_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/214_licenced_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/220_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/223_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/228_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/231_licenced_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/232_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/245_Expired_Notified_Building_1_2017.png
#   inflating: Filtered Data/filtered_images/train/248_licenced_Building_1_2017.png
#   inflating: Filtered Data/filtered_images/train/252_Expired_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/275_licenced_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/299_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/300_Expired_Notified_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/301_licenced_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/309_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/321_Expired_Notified_Building_1_2019.png
#   inflating: Filtered Data/filtered_images/train/334_Expired_Notified_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/34_licenced_Small_1_2022.png
#   inflating: Filtered Data/filtered_images/train/344_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/356_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/362_Expired_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/38_licenced_Small_1_2016.png
#   inflating: Filtered Data/filtered_images/train/385_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/389_licenced_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/40_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/41_Expired_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/417_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/423_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/424_licenced_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/424_licenced_Building_1_2019.png
#   inflating: Filtered Data/filtered_images/train/441_Expired_Notified_Building_1_2017.png
#   inflating: Filtered Data/filtered_images/train/446_Expired_Notified_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/450_Expired_Notified_Building_1_2019.png
#   inflating: Filtered Data/filtered_images/train/469_licenced_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/470_Expired_Notified_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/479_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/485_Expired_Notified_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/492_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/493_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/496_licenced_Building_1_2019.png
#   inflating: Filtered Data/filtered_images/train/498_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/499_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/499_licenced_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/499_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/500_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/505_Expired_Notified_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/512_licenced_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/516_licenced_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/517_Expired_Notified_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/52_licenced_Small_1_2015.png
#   inflating: Filtered Data/filtered_images/train/53_licenced_Small_1_2019.png
#   inflating: Filtered Data/filtered_images/train/566_Expired_Notified_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/566_Expired_Notified_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/568_Expired_Exploration_1_2016.png
#   inflating: Filtered Data/filtered_images/train/58_licenced_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/580_Expired_Notified_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/595_Expired_Notified_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/601_Expired_Notified_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/623_Expired_Building_1_2019.png
#   inflating: Filtered Data/filtered_images/train/63_Renew_Licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/638_Expired_Notified_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/645_licenced_Building_1_2021.png
#   inflating: Filtered Data/filtered_images/train/679_Expired_Notified_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/695_Expired_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/701_Expired_Notified_Building_1_2020.png
#   inflating: Filtered Data/filtered_images/train/708_licenced_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/716_Expired_Notified_Building_1_2015.png
#   inflating: Filtered Data/filtered_images/train/716_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/73_licenced_Raw_1_2014.png
#   inflating: Filtered Data/filtered_images/train/730_licenced_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/746_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_images/train/751_Expired_Notified_Building_1_2016.png
#   inflating: Filtered Data/filtered_images/train/776_licenced_Building_1_2014.png
#   inflating: Filtered Data/filtered_images/train/783_Expired_Notified_Building_1_2018.png
#   inflating: Filtered Data/filtered_images/train/798_licenced_Building_1_2022.png
#   inflating: Filtered Data/filtered_images/train/810_Expired_Notified_Building_1_2023.png
#   inflating: Filtered Data/filtered_labels/train/1137_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1148_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1150_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/119_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/1198_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/12_licenced_Small_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1207_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/1210_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/1213_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/1213_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1219_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/1219_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/1222_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1224_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/1262_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1266_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1268_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/1275_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/1279_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/1280_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/1282_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/130_Renew_Licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/1313_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1315_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/1322_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/1333_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1334_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/1347_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/135_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1362_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/1371_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1372_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1393_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1436_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/1448_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1451_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1474_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/1483_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/15_Renew_Licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/1507_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/1525_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1548_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/1551_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/1554_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/167_Expired_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/180_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/2_Expired_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/214_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/220_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/223_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/228_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/231_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/232_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/245_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/248_licenced_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/252_Expired_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/275_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/299_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/300_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/301_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/309_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/321_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/334_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/34_licenced_Small_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/344_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/356_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/362_Expired_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/38_licenced_Small_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/385_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/389_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/40_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/41_Expired_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/417_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/423_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/424_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/424_licenced_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/441_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/train/446_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/450_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/469_licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/470_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/479_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/485_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/492_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/493_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/496_licenced_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/498_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/499_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/499_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/499_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/500_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/505_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/512_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/516_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/517_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/52_licenced_Small_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/53_licenced_Small_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/566_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/566_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/568_Expired_Exploration_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/58_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/580_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/595_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/601_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/623_Expired_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/63_Renew_Licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/638_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/645_licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/679_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/695_Expired_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/701_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/708_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/716_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/716_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/73_licenced_Raw_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/730_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/746_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/751_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/776_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/783_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/798_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/810_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/832_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/847_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/848_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/865_licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/868_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/875_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/891_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/90_Renew_Licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/909_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/91_Renew_Licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/925_licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/929_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/931_Expired_Notified_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/931_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/934_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/942_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/951_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/978_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/987_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/990_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/71_licenced_Small_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/772_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/824_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/83_licenced_Raw_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/849_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/85_licenced_Raw_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/9_licenced_Small_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/904_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/925_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/939_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/108_Renew_Licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1080_Expired_Notified_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/train/118_Renew_Licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/123_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1240_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/train/1264_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1304_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/14_licenced_Raw_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/1417_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/1425_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/1476_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/train/1480_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/train/153_Expired_Exploration_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/161_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/17_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/18_licenced_Small_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/2_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/200_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/21_Renew_Licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/22_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/236_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/242_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/25_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/train/27_licenced_Small_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/28_licenced_Raw_1_2014.txt
#   inflating: Filtered Data/filtered_labels/train/335_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/train/35_licenced_Small_1_2020.txt
#   inflating: Filtered Data/filtered_labels/train/374_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/train/386_Expired_Notified_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/val/1425_Expired_Notified_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/val/1476_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/val/1480_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/val/153_Expired_Exploration_1_2018.txt
#   inflating: Filtered Data/filtered_labels/val/161_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/val/17_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/val/18_licenced_Small_1_2016.txt
#   inflating: Filtered Data/filtered_labels/val/2_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/val/200_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/val/21_Renew_Licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/val/22_licenced_Building_1_2020.txt
#    creating: Filtered Data/filtered_labels/val/xml_annotations/
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/71_licenced_Small_1_2023.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/772_Expired_Notified_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/824_Expired_Notified_Building_1_2019.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/83_licenced_Raw_1_2014.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/849_licenced_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/85_licenced_Raw_1_2016.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/9_licenced_Small_1_2019.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/904_Expired_Notified_Building_1_2016.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/925_Expired_Notified_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/939_Expired_Notified_Building_1_2019.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/108_Renew_Licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1080_Expired_Notified_Building_1_2021.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/118_Renew_Licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/123_licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1240_Expired_Notified_Building_1_2022.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1264_Expired_Notified_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1304_Expired_Notified_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/14_licenced_Raw_1_2019.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1417_licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1425_Expired_Notified_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1476_Expired_Notified_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/1480_Expired_Notified_Building_1_2019.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/153_Expired_Exploration_1_2018.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/161_licenced_Building_1_2023.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/17_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/18_licenced_Small_1_2016.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/2_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/200_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/21_Renew_Licenced_Building_1_2023.xml
#   inflating: Filtered Data/filtered_labels/val/xml_annotations/22_licenced_Building_1_2020.xml
#    creating: Filtered Data/filtered_labels/test/
#   inflating: Filtered Data/filtered_labels/test/1035_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/1044_licenced_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/test/1055_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/test/1272_licenced_Building_1_2021.txt
#   inflating: Filtered Data/filtered_labels/test/143_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/1489_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/test/1496_licenced_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/test/1545_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/17_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/187_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/test/2_licenced_Small_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/222_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/test/307_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/test/371_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/test/39_licenced_Raw_1_2016.txt
#   inflating: Filtered Data/filtered_labels/test/422_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/test/428_Expired_Notified_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/test/432_Expired_Notified_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/461_Expired_Building_1_2023.txt
#   inflating: Filtered Data/filtered_labels/test/478_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/test/525_licenced_Building_1_2014.txt
#   inflating: Filtered Data/filtered_labels/test/549_Expired_Notified_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/test/568_Expired_Notified_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/test/581_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/test/606_licenced_Building_1_2020.txt
#   inflating: Filtered Data/filtered_labels/test/649_Expired_Notified_Building_1_2017.txt
#   inflating: Filtered Data/filtered_labels/test/75_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/test/786_licenced_Building_1_2019.txt
#   inflating: Filtered Data/filtered_labels/test/830_licenced_Building_1_2018.txt
#   inflating: Filtered Data/filtered_labels/test/837_Expired_Notified_Building_1_2016.txt
#   inflating: Filtered Data/filtered_labels/test/872_licenced_Building_1_2015.txt
#   inflating: Filtered Data/filtered_labels/test/89_licenced_Building_1_2022.txt
#   inflating: Filtered Data/filtered_labels/test/962_licenced_Building_1_2015.txt
#    creating: Filtered Data/filtered_labels/test/xml_annotations/
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1035_licenced_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1044_licenced_Building_1_2023.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1055_Expired_Notified_Building_1_2017.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1272_licenced_Building_1_2021.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/143_Expired_Notified_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1489_licenced_Building_1_2022.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1496_licenced_Building_1_2016.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/1545_Expired_Notified_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/17_Expired_Notified_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/187_licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/2_licenced_Small_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/222_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/307_Expired_Notified_Building_1_2016.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/371_Expired_Notified_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/39_licenced_Raw_1_2016.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/422_licenced_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/428_Expired_Notified_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/432_Expired_Notified_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/461_Expired_Building_1_2023.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/478_Expired_Notified_Building_1_2016.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/525_licenced_Building_1_2014.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/549_Expired_Notified_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/568_Expired_Notified_Building_1_2019.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/581_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/606_licenced_Building_1_2020.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/649_Expired_Notified_Building_1_2017.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/75_licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/786_licenced_Building_1_2019.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/830_licenced_Building_1_2018.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/837_Expired_Notified_Building_1_2016.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/872_licenced_Building_1_2015.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/89_licenced_Building_1_2022.xml
#   inflating: Filtered Data/filtered_labels/test/xml_annotations/962_licenced_Building_1_2015.xml

# %%
import torch
import torchvision
import torchvision.models as models
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection import fasterrcnn_resnet50_fpn
import os
import xmltodict
import numpy as np
import cv2
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch.optim as optim
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torchmetrics
from tqdm import tqdm


import warnings
warnings.filterwarnings("ignore")

# %%
# Load pre-trained Faster R-CNN with FPN
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

# Modify the classifier to detect only 1 class (building) +   background
num_classes = 2  # 1 (building) + 1 (background)
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#   )
# )

# %%
class PascalVOCDataset(Dataset):
    def __init__(self, images_dir, annotations_dir, transform=None):
        self.images_dir = images_dir
        self.annotations_dir = annotations_dir
        self.transform = transform
        self.image_files = [f for f in os.listdir(images_dir) if f.endswith('.png')]

        # Filter images with 'building' annotations
        self.image_files = [f for f in self.image_files if self._has_building_annotation(f)]
        print(f"Filtered dataset! Found {len(self.image_files)} images with 'building' annotations.")

    def _has_building_annotation(self, img_name):
        xml_path = os.path.join(self.annotations_dir, img_name.replace('.png', '.xml'))

        # Read the XML annotation file
        try:
            with open(xml_path, "r") as f:
                annotation = xmltodict.parse(f.read())
            # Check if "building" is in the annotation
            objects = annotation["annotation"].get("object", [])
            if isinstance(objects, dict):  # If only one object, wrap it in a list
                objects = [objects]
            for obj in objects:
                if obj["name"].lower() == "building":
                    return True
        except Exception as e:
            print(f"Error reading {xml_path}: {e}")
        return False

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.images_dir, img_name)
        xml_path = os.path.join(self.annotations_dir, img_name.replace('.png', '.xml'))

        # Load image
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Load XML annotation
        with open(xml_path, "r") as f:
            annotation = xmltodict.parse(f.read())

        # Extract bounding boxes and labels
        boxes = []
        labels = []
        objects = annotation["annotation"].get("object", [])
        if isinstance(objects, dict):
            objects = [objects]

        for obj in objects:
            if obj["name"].lower() != "building":
                continue
            bbox = obj["bndbox"]
            x_min = int(bbox["xmin"])
            y_min = int(bbox["ymin"])
            x_max = int(bbox["xmax"])
            y_max = int(bbox["ymax"])
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(1)  # Class label for 'building'

        # Initialize target
        target = {"boxes": boxes, "labels": labels}

        # Apply transformations
        if self.transform:
            transformed = self.transform(image=image, bboxes=boxes, labels=labels)
            image = transformed["image"]
            # Convert transformed bboxes and labels to tensors
            target["boxes"] = torch.tensor(transformed["bboxes"], dtype=torch.float32)
            target["labels"] = torch.tensor(transformed["labels"], dtype=torch.int64)
        else:
            # Convert boxes and labels to tensors if no transform applied
            target["boxes"] = torch.tensor(boxes, dtype=torch.float32)
            target["labels"] = torch.tensor(labels, dtype=torch.int64)

        return image, target

# %%
# Define transformations
transform = A.Compose([
    A.Resize(640, 640),
    A.HorizontalFlip(p=0.5),
    A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ToTensorV2(),
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))

# %%
TRAIN_IMG_DIR = "/content/Filtered Data/filtered_images/train"
TRAIN_ANNOT_DIR = "/content/Filtered Data/filtered_labels/train/xml_annotations"

TEST_IMG_DIR = "/content/Filtered Data/filtered_images/test"
TEST_ANNOT_DIR = "/content/Filtered Data/filtered_labels/test/xml_annotations"

VAL_IMG_DIR = "/content/Filtered Data/filtered_images/val"
VAL_ANNOT_DIR = "/content/Filtered Data/filtered_labels/val/xml_annotations"

# %%
# Create datasets for train, val, and test
train_dataset = PascalVOCDataset(TRAIN_IMG_DIR, TRAIN_ANNOT_DIR, transform=transform)
val_dataset = PascalVOCDataset(VAL_IMG_DIR, VAL_ANNOT_DIR, transform=transform)
test_dataset = PascalVOCDataset(TEST_IMG_DIR, TEST_ANNOT_DIR, transform=transform)

# Create DataLoader for each dataset
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))
# Out:
# Filtered dataset! Found 208 images with 'building' annotations.
# Filtered dataset! Found 30 images with 'building' annotations.
# Filtered dataset! Found 33 images with 'building' annotations.

# %%
# Define optimizer for Faster R-CNN
params = [p for p in model.parameters() if p.requires_grad]
# Using a common choice of learning rate and momentum for Faster R-CNN
optimizer = optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)

# Optional: Define a learning rate scheduler (for better performance)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
# Training loop with validation loss
num_epochs = 10
best_val_loss = float('inf')  # Track best validation loss for saving models

for epoch in range(num_epochs):
    # --- Training Phase ---
    model.train()
    train_loss = 0

    for images, targets in train_loader:
        # Move data to device
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        # Forward pass
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())

        # Backward pass
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        train_loss += losses.item()

    # --- Validation Phase ---
    model.eval()  # Switch to evaluation mode (affects layers like dropout)
    val_loss = 0

    with torch.no_grad():  # Disable gradient calculation
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            # Forward pass (returns losses if in train mode, but we use eval mode)
            # To get validation loss, temporarily switch to train mode:
            model.train()
            loss_dict = model(images, targets)
            model.eval()

            val_loss += sum(loss for loss in loss_dict.values()).item()

    # Calculate epoch metrics
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)

    # Update learning rate scheduler
    lr_scheduler.step()  # Optional but recommended

    # Print progress
    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"  Train Loss: {avg_train_loss:.4f}")
    print(f"  Val Loss: {avg_val_loss:.4f}")
    print(f"  Learning Rate: {optimizer.param_groups[0]['lr']:.6f}\n")

    # Optional: Save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), "best_model.pth")
# Out:
# Epoch 1/10
#   Train Loss: 1.1176
#   Val Loss: 1.1405
#   Learning Rate: 0.005000
#
# Epoch 2/10
#   Train Loss: 0.8353
#   Val Loss: 0.9352
#   Learning Rate: 0.005000
#
# Epoch 3/10
#   Train Loss: 0.7567
#   Val Loss: 0.8997
#   Learning Rate: 0.000500
#
# Epoch 4/10
#   Train Loss: 0.7083
#   Val Loss: 0.8666
#   Learning Rate: 0.000500
#
# Epoch 5/10
#   Train Loss: 0.6833
#   Val Loss: 0.8666
#   Learning Rate: 0.000500
#
# Epoch 6/10
#   Train Loss: 0.6795
#   Val Loss: 0.8508
#   Learning Rate: 0.000050
#
# Epoch 7/10
#   Train Loss: 0.6671
#   Val Loss: 0.8494
#   Learning Rate: 0.000050
#
# Epoch 8/10
#   Train Loss: 0.6649
#   Val Loss: 0.8730
#   Learning Rate: 0.000050
#
# Epoch 9/10
#   Train Loss: 0.6693
#   Val Loss: 0.8702
#   Learning Rate: 0.000005
#
# Epoch 10/10
#   Train Loss: 0.6554
#   Val Loss: 0.8551
#   Learning Rate: 0.000005

# %%
model.eval()

# Initialize mAP metric and loss tracking
map_metric = torchmetrics.detection.MeanAveragePrecision()
test_loss = 0
num_batches = 0

with torch.no_grad():
    for images, targets in tqdm(test_loader):
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        # --- Step 1: Calculate Test Loss (Optional) ---
        # Temporarily switch to train mode to compute loss
        model.train()
        loss_dict = model(images, targets)  # Returns loss dictionary
        losses = sum(loss for loss in loss_dict.values())
        test_loss += losses.item()
        num_batches += 1

        # --- Step 2: Generate Predictions for mAP ---
        # Switch back to eval mode for inference
        model.eval()
        predictions = model(images)  # Returns list of prediction dicts

        # Update mAP metric
        for pred, true in zip(predictions, targets):
            map_metric.update(
                preds=[{
                    "boxes": pred["boxes"],
                    "scores": pred["scores"],
                    "labels": pred["labels"]
                }],
                target=[{
                    "boxes": true["boxes"],
                    "labels": true["labels"]
                }]
            )

# Compute metrics
avg_test_loss = test_loss / num_batches
map_score = map_metric.compute()

print(f"Test Loss: {avg_test_loss:.4f}")
print(f"mAP: {map_score['map']:.4f}")
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.16it/s]
# Test Loss: 0.8839
# mAP: 0.0782
